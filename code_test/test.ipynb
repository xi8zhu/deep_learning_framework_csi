# %%
a = 
a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 2
#       1 a = 
# ----> 2 a.shape
#
# AttributeError: 'int' object has no attribute 'shape'

# %%
a = 1e202
a
# Out:
# 1e+202

# %%
a = 1e999
a
# Out:
# inf
